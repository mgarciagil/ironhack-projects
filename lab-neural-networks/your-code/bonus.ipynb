# %% [markdown]
# # Bonus Challenge: Spiral Data Classification
#
# Now that you completed Challenge 2, you know you can use the Tensorflow Playground to experiment the hyperparameters of your deep learning model. If you are brave enough to take on this challenge, we present you the spiral data generated by codes and you will replicate your model built visually in the Tensorflow Playground with Python codes.
#
# Below are the codes to generate the spiral dataset. Read the remarks and execute the codes.

# %%
from math import hypot, cos, sin
import numpy as np
import pandas as pd

"""
A function to generate X/Y data points that will form a spiral.
"""
def spiral(radius, step, resolution=.1, angle=0.0, start=0.0):
    dist = start
    coords=[]
    while dist*hypot(cos(angle),sin(angle))<radius:
        cord=[]
        cord.append(dist*cos(angle))
        cord.append(dist*sin(angle))
        coords.append(cord)
        dist+=step
        angle+=resolution
    return coords

# %%
# Generate two sets of spiral data points with opposite angles
data_1 = np.array(spiral(1000, 5, angle=0))
data_2 = np.array(spiral(1000, 5, angle=180))

# %%
# Plot the two datasets to visualize the spirals

import matplotlib.pyplot as plt

a, b = data_1.T
plt.scatter(a, b, s=5)

aa, bb = data_2.T
plt.scatter(aa, bb, s=5)

plt.show()

# %%
# Combine the two spiral datasets into one

df1 = pd.DataFrame(data=data_1, columns=["X", "Y"])
df1["CLASS"] = 0

df2 = pd.DataFrame(data=data_2, columns=["X", "Y"])
df2["CLASS"] = 1

df = df1.append(df2)
df['CLASS'].value_counts()
# Out:
# 1    201
# 0    200
# Name: CLASS, dtype: int64

# %% [markdown]
# Now, build a neural network with Tensorflow to classify `df`. See how low data loss and how high accuracy can you achieve!

# %%
# your code here
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

df.columns


X = df[['X', 'Y']]
y = df['CLASS']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_train = tf.keras.utils.normalize(X_train, axis = 1)
X_test = tf.keras.utils.normalize(X_test, axis = 1)

# %%
# NOT WORKING. Keep playing with the neural playground

model = keras.Sequential()

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(5, activation = tf.nn.tanh))
model.add(tf.keras.layers.Dense(3, activation = tf.nn.tanh))
#model.add(tf.keras.layers.Dense(1024, activation = tf.nn.relu))
#model.add(tf.keras.layers.Dense(1024, activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(2, activation = tf.nn.tanh))


tf.keras.optimizers.Adam(
    learning_rate=0.03, 
    beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6f50504c6c17> in <module>
#      17 model.compile(optimizer = 'adam', loss = 'categorical_crossentropy' , metrics = ['accuracy'])
#      18
# ---> 19 model.fit(X_train, y_train, epochs = 20)
#
# /home/mgarcia/snap/jupyter/common/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /home/mgarcia/snap/jupyter/common/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     641         steps=steps_per_epoch,
#     642         validation_split=validation_split,
# --> 643         shuffle=shuffle)
#     644
#     645     if validation_data:
#
# /home/mgarcia/snap/jupyter/common/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2416     # First, we build the model on the fly if necessary.
#    2417     if not self.inputs:
# -> 2418       all_inputs, y_input, dict_inputs = self._build_model_with_inputs(x, y)
#    2419       is_build_called = True
#    2420     else:
#
# /home/mgarcia/snap/jupyter/common/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in _build_model_with_inputs(self, inputs, targets)
#    2579     # or lists of arrays, and extract a flat list of inputs from the passed
#    2580     # structure.
# -> 2581     training_utils.validate_input_types(inputs, orig_inputs)
#    2582
#    2583     if isinstance(inputs, (list, tuple)):
#
# /home/mgarcia/snap/jupyter/common/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py in validate_input_types(inp, orig_inp, allow_dict, field_name)
#    1147     raise ValueError(
#    1148         'Please provide as model inputs either a single array or a list of '
# -> 1149         'arrays. You passed: {}={}'.format(field_name, orig_inp))
#    1150
#    1151
#
# ValueError: Please provide as model inputs either a single array or a list of arrays. You passed: inputs=            X         Y
# 51   0.377978 -0.925815
# 60   0.960170 -0.279415
# 100  0.066307  0.997799
# 131 -0.107739 -0.994179
# 35   0.279401  0.960174
# ..        ...       ...
# 182 -0.961149 -0.276032
# 113  0.299745 -0.954019
# 146  0.984068 -0.177794
# 189 -0.557303 -0.830310
# 5    0.877583  0.479426
#
# [320 rows x 2 columns]
